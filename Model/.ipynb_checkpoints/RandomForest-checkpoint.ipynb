# %%
import sys  
sys.path.append("../../")
from LIB.utils import *

# %%
v="v6"

train_df=pd.read_csv("../features/train_{}.csv".format(v))
test_df=pd.read_csv("../features/test_{}.csv".format(v))

# %%
# train_df.Sales_first_7_days=np.log1p(train_df.Sales_first_7_days)
# test_df.Sales_first_7_days=np.log1p(test_df.Sales_first_7_days)

# %%
train_df.columns
# Out:
# Index(['ID', 'month', 'sku_hash', 'product_type', 'product_gender',
#        'macro_function', 'function', 'sub_function', 'model',
#        'aesthetic_sub_line',
#        ...
#        'rez_net46', 'rez_net47', 'rez_net48', 'rez_net49',
#        'Sales_first_7_days', 'first_month_sales', 'ratio',
#        'count_sales_per_month', 'price_ratio', 'views_count'],
#       dtype='object', length=113)

# %%
keys= ["ID"]
Target_name="target_log"
not_used_cols=["ID",'sku_hash', 'product_type', 'product_gender',
       'macro_function', 'function', 'sub_function', 'model',
       'aesthetic_sub_line', 'macro_material', 'color', 'fr_FR_price',
       'en_US_description', 'target', 'target_log',
                'ratio_function_month1_2',
  'ratio_function_month2_3',
  'ratio_function_month1_3',"ratio","count_sales_per_month",
              
              "price_ratio","views_count"]
    

feautres_name=[ f for f in test_df.columns if f not in not_used_cols]
from sklearn.metrics import mean_squared_error
def eval_metrics(y_ture,y_hat):
    return np.sqrt(mean_squared_error(y_ture,y_hat))

# %%
len(feautres_name),feautres_name
# Out:
# (94,
#  ['month',
#   'target_log_by_product_type_mean',
#   'target_log_by_product_type_min',
#   'target_log_by_product_type_std',
#   'target_log_by_product_gender_mean',
#   'target_log_by_product_gender_min',
#   'target_log_by_product_gender_std',
#   'target_log_by_macro_function_mean',
#   'target_log_by_macro_function_min',
#   'target_log_by_macro_function_std',
#   'target_log_by_function_mean',
#   'target_log_by_function_min',
#   'target_log_by_function_std',
#   'target_log_by_sub_function_mean',
#   'target_log_by_sub_function_min',
#   'target_log_by_sub_function_std',
#   'target_log_by_aesthetic_sub_line_mean',
#   'target_log_by_aesthetic_sub_line_min',
#   'target_log_by_aesthetic_sub_line_std',
#   'target_log_by_macro_material_mean',
#   'target_log_by_macro_material_min',
#   'target_log_by_macro_material_std',
#   'type_tf_idf_pca_0',
#   'type_tf_idf_pca_1',
#   'type_tf_idf_pca_2',
#   'type_tf_idf_pca_3',
#   'type_tf_idf_pca_4',
#   'type_tf_idf_pca_5',
#   'type_tf_idf_pca_6',
#   'type_tf_idf_pca_7',
#   'type_tf_idf_pca_8',
#   'type_tf_idf_pca_9',
#   'type_tf_idf_pca_10',
#   'type_tf_idf_pca_11',
#   'type_tf_idf_pca_12',
#   'type_tf_idf_pca_13',
#   'type_tf_idf_pca_14',
#   'type_tf_idf_pca_15',
#   'type_tf_idf_pca_16',
#   'type_tf_idf_pca_17',
#   'type_tf_idf_pca_18',
#   'type_tf_idf_pca_19',
#   'rez_net0',
#   'rez_net1',
#   'rez_net2',
#   'rez_net3',
#   'rez_net4',
#   'rez_net5',
#   'rez_net6',
#   'rez_net7',
#   'rez_net8',
#   'rez_net9',
#   'rez_net10',
#   'rez_net11',
#   'rez_net12',
#   'rez_net13',
#   'rez_net14',
#   'rez_net15',
#   'rez_net16',
#   'rez_net17',
#   'rez_net18',
#   'rez_net19',
#   'rez_net20',
#   'rez_net21',
#   'rez_net22',
#   'rez_net23',
#   'rez_net24',
#   'rez_net25',
#   'rez_net26',
#   'rez_net27',
#   'rez_net28',
#   'rez_net29',
#   'rez_net30',
#   'rez_net31',
#   'rez_net32',
#   'rez_net33',
#   'rez_net34',
#   'rez_net35',
#   'rez_net36',
#   'rez_net37',
#   'rez_net38',
#   'rez_net39',
#   'rez_net40',
#   'rez_net41',
#   'rez_net42',
#   'rez_net43',
#   'rez_net44',
#   'rez_net45',
#   'rez_net46',
#   'rez_net47',
#   'rez_net48',
#   'rez_net49',
#   'Sales_first_7_days',
#   'first_month_sales'])

# %%
from LIB.lgbm_model import * 
params={ 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.01,
         "feature_fraction": 0.7,
         "bagging_freq": 2,
         "bagging_seed": 15,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "num_threads" :8}



LGBM= lightgbm_model( Train_df=train_df,
                        Test_df=test_df,
                        feval_metrics=eval_metrics,
                        Target_name=Target_name,
                        params=params,
                        feature_names=feautres_name,
                        keys=keys,
                        verbose_eval=50,
                        early_stopping_rounds=20,
                        num_boost_round=20000,
                        maximize=False,
                        test_size=0.15,
                        nbr_fold=5,
                        nbr_run=2,
                    random_state=15)
train_pred_lgbm,test_pred_lgbm=LGBM.lightgbm_Kfold()

LGBM.plot_importance()
# Out:
# ##################################################fold:1##################################################
# run 0 train metrics :0.10259962058767978 val metrics : 0.39035554123894567
# run 1 train metrics :0.08804639315585634 val metrics : 0.38737999612848806
#
# fold-1 train metrics :0.09532300687176806 val metrics : 0.38886776868371686
# ##################################################fold:2##################################################
# run 0 train metrics :0.10036431543167952 val metrics : 0.37260073861057497
# run 1 train metrics :0.0973665359908975 val metrics : 0.3716481148591651
#
# fold-2 train metrics :0.09886542571128851 val metrics : 0.37212442673487
# ##################################################fold:3##################################################
# run 0 train metrics :0.07618908710929637 val metrics : 0.3934724826897547
# run 1 train metrics :0.06590582551611548 val metrics : 0.3924939642174523
#
# fold-3 train metrics :0.07104745631270593 val metrics : 0.3929832234536035
# ##################################################fold:4##################################################
# run 0 train metrics :0.08516669004273866 val metrics : 0.40613916890300755
# run 1 train metrics :0.08210166125777155 val metrics : 0.4051692155885035
#
# fold-4 train metrics :0.0836341756502551 val metrics : 0.4056541922457555
# ##################################################fold:5##################################################
# run 0 train metrics :0.12309041269036292 val metrics : 0.3798576074088346
# run 1 train metrics :0.10834871617124302 val metrics : 0.3763680362281455
#
# fold-5 train metrics :0.11571956443080297 val metrics : 0.37811282181849004
# End Training with  train metrics :0.0929179257953641 val metrics : 0.38754848658728713

# %%
test_pred_lgbm["target"]=np.expm1(test_pred_lgbm.target_log).round()

# %%
# test_pred_xgboost["target"]=test_pred_xgboost.target_log

# %%
test_pred_lgbm[["ID","target"]].to_csv("../sub/lgbm.csv",index=False)

# %%
len(test_pred_lgbm)
# Out:
# 5166
